# %%
import gym
import numpy as np
import random
from collections import deque
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam
# Out:
# Using TensorFlow backend.

# %%
ENV_NAME = 'Acrobot-v1'

GAMMA = .5
LEARNING_RATE = .001

MEMORY_SIZE = 1000000
BATCH_SIZE = 20

EXPLORATION_MAX = 1
EXPLORATION_MIN = .01
EXPLORATION_DECAY = .99995

class DQNSolver:
    
    def __init__(self, observation_space, action_space):
        self.explore_rate = EXPLORATION_MAX
        
        self.action_space = action_space
        self.memory = deque(maxlen=MEMORY_SIZE)
        
        self.model = Sequential()
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))
        self.model.add(Dense(24, activation="relu"))
        self.model.add(Dense(self.action_space, activation="linear"))
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))
    
    def remember(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))
        
    def act(self, state):
        if np.random.rand() < self.explore_rate:
            return random.randrange(self.action_space)
        q_values = self.model.predict(state)
        return np.argmax(q_values)
        
    def experience_replay(self):
        if len(self.memory) < BATCH_SIZE:
            return
        batch = random.sample(self.memory, BATCH_SIZE)
        for state, action, reward, state_next, done in batch:
            q_update = reward
            if not done:
                q_update = (reward + GAMMA * np.argmax(self.model.predict(state_next)[0]))
            q_values = self.model.predict(state)
            q_values[0][action] = q_update
            self.model.fit(state, q_values, verbose=0)
        self.explore_rate *= EXPLORATION_DECAY
        self.explore_rate = max(self.explore_rate, EXPLORATION_MIN)

# %%
def acrobot():
    env = gym.make(ENV_NAME)
    observation_space = env.observation_space.shape[0]
    action_space = env.action_space.n
    dqn_solver = DQNSolver(observation_space, action_space)
    run = 0
    while run < 200:
        run += 1
        state = env.reset()
        state = np.reshape(state, [1, observation_space])
        step = 0
        progress = 0
        penalties = 0
        while True:
            step += 1
            env.render()
            action = dqn_solver.act(state)
            state_next, reward, done, info = env.step(action)
            if reward > 0: 
                progress += reward
            else:
                penalties += reward
            state_next = np.reshape(state_next, [1, observation_space])
            dqn_solver.remember(state, action, reward, state_next, done)
            state = state_next
            if done:
                print(f"Run: {run} exploration: {dqn_solver.explore_rate}")
                print(f"Progress: {progress}, Penalties: {penalties}")
                break
            dqn_solver.experience_replay()
    
acrobot()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0717 13:51:09.970468 140046005827392 deprecation_wrapper.py:119] From /home/tomas/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0717 13:51:09.986757 140046005827392 deprecation_wrapper.py:119] From /home/tomas/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0717 13:51:09.988723 140046005827392 deprecation_wrapper.py:119] From /home/tomas/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0717 13:51:10.037181 140046005827392 deprecation_wrapper.py:119] From /home/tomas/anaconda3/lib/python3.6/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0717 13:51:10.612556 140046005827392 deprecation_wrapper.py:119] From /home/tomas/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0717 13:51:10.619303 140046005827392 deprecation_wrapper.py:119] From /home/tomas/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
# Run: 1 exploration: 0.9762851239671341
# Progress: 0, Penalties: -500.0
# Run: 2 exploration: 0.9522275746171881
# Progress: 0, Penalties: -500.0
# Run: 3 exploration: 0.9287628497060423
# Progress: 0, Penalties: -500.0
# Run: 4 exploration: 0.9058763408955779
# Progress: 0, Penalties: -500.0
# Run: 5 exploration: 0.883553799825314
# Progress: 0, Penalties: -500.0
# Run: 6 exploration: 0.8617813292418679
# Progress: 0, Penalties: -500.0
# Run: 7 exploration: 0.8405453743469987
# Progress: 0, Penalties: -500.0
# Run: 8 exploration: 0.8198327143588462
# Progress: 0, Penalties: -500.0
# Run: 9 exploration: 0.7996304542811299
# Progress: 0, Penalties: -500.0
# Run: 10 exploration: 0.7799260168751616
# Progress: 0, Penalties: -500.0
# Run: 11 exploration: 0.7607071348296816
# Progress: 0, Penalties: -500.0
# Run: 12 exploration: 0.7419618431236511
# Progress: 0, Penalties: -500.0
# Run: 13 exploration: 0.7236784715772421
# Progress: 0, Penalties: -500.0
# Run: 14 exploration: 0.7058456375863705
# Progress: 0, Penalties: -500.0
# Run: 15 exploration: 0.688452239036286
# Progress: 0, Penalties: -500.0
# Run: 16 exploration: 0.6714874473897701
# Progress: 0, Penalties: -500.0
# Run: 17 exploration: 0.6549407009456503
# Progress: 0, Penalties: -500.0
# Run: 18 exploration: 0.6388016982634587
# Progress: 0, Penalties: -500.0
# Run: 19 exploration: 0.6230603917500955
# Progress: 0, Penalties: -500.0
# Run: 20 exploration: 0.607706981404544
# Progress: 0, Penalties: -500.0
# Run: 21 exploration: 0.5927319087167233
# Progress: 0, Penalties: -500.0
# Run: 22 exploration: 0.578125850716683
# Progress: 0, Penalties: -500.0
# Run: 23 exploration: 0.5638797141704467
# Progress: 0, Penalties: -500.0
# Run: 24 exploration: 0.5499846299188639
# Progress: 0, Penalties: -500.0
# Run: 25 exploration: 0.5364319473559886
# Progress: 0, Penalties: -500.0
# Run: 26 exploration: 0.5232132290434903
# Progress: 0, Penalties: -500.0
# Run: 27 exploration: 0.5103202454578021
# Progress: 0, Penalties: -500.0
# Run: 28 exploration: 0.49774496986670175
# Progress: 0, Penalties: -500.0
# Run: 29 exploration: 0.48547957333213493
# Progress: 0, Penalties: -500.0
# Run: 30 exploration: 0.4735164198361885
# Progress: 0, Penalties: -500.0
# Run: 31 exploration: 0.46184806152716434
# Progress: 0, Penalties: -500.0
# Run: 32 exploration: 0.45046723408280315
# Progress: 0, Penalties: -500.0
# Run: 33 exploration: 0.43936685218776356
# Progress: 0, Penalties: -500.0
# Run: 34 exploration: 0.4285400051225472
# Progress: 0, Penalties: -500.0
# Run: 35 exploration: 0.41797995246111913
# Progress: 0, Penalties: -500.0
# Run: 36 exploration: 0.40768011987454783
# Progress: 0, Penalties: -500.0
# Run: 37 exploration: 0.40249494065316654
# Progress: 0, Penalties: -256.0
# Run: 38 exploration: 0.39257668863830464
# Progress: 0, Penalties: -500.0
# Run: 39 exploration: 0.38290284149191345
# Progress: 0, Penalties: -500.0
# Run: 40 exploration: 0.37346737660641544
# Progress: 0, Penalties: -500.0
# Run: 41 exploration: 0.3642644197829067
# Progress: 0, Penalties: -500.0
# Run: 42 exploration: 0.35528824157407873
# Progress: 0, Penalties: -500.0
# Run: 43 exploration: 0.3465332537172608
# Progress: 0, Penalties: -500.0
# Run: 44 exploration: 0.33799400565535814
# Progress: 0, Penalties: -500.0
# Run: 45 exploration: 0.32966518114352045
# Progress: 0, Penalties: -500.0
# Run: 46 exploration: 0.3215415949394292
# Progress: 0, Penalties: -500.0
# Run: 47 exploration: 0.31361818957514165
# Progress: 0, Penalties: -500.0
# Run: 48 exploration: 0.3058900322084845
# Progress: 0, Penalties: -500.0
# Run: 49 exploration: 0.2983523115520347
# Progress: 0, Penalties: -500.0
# Run: 50 exploration: 0.291000334877775
# Progress: 0, Penalties: -500.0
# Run: 51 exploration: 0.283829525095562
# Progress: 0, Penalties: -500.0
# Run: 52 exploration: 0.2768354179035851
# Progress: 0, Penalties: -500.0
# Run: 53 exploration: 0.27001365900904684
# Progress: 0, Penalties: -500.0
# Run: 54 exploration: 0.2633600014173243
# Progress: 0, Penalties: -500.0
# Run: 55 exploration: 0.2568703027879382
# Progress: 0, Penalties: -500.0
# Run: 56 exploration: 0.2505405228556727
# Progress: 0, Penalties: -500.0
# Run: 57 exploration: 0.24436672091524225
# Progress: 0, Penalties: -500.0
# Run: 58 exploration: 0.23834505336794407
# Progress: 0, Penalties: -500.0
# Run: 59 exploration: 0.23247177132876368
# Progress: 0, Penalties: -500.0
# Run: 60 exploration: 0.22674321829244865
# Progress: 0, Penalties: -500.0
# Run: 61 exploration: 0.22115582785709084
# Progress: 0, Penalties: -500.0
# Run: 62 exploration: 0.215706121503807
# Progress: 0, Penalties: -500.0
# Run: 63 exploration: 0.21039070643113214
# Progress: 0, Penalties: -500.0
# Run: 64 exploration: 0.2052062734427758
# Progress: 0, Penalties: -500.0
# Run: 65 exploration: 0.20014959488742973
# Progress: 0, Penalties: -500.0
# Run: 66 exploration: 0.19521752264934236
# Progress: 0, Penalties: -500.0
# Run: 67 exploration: 0.19040698618840896
# Progress: 0, Penalties: -500.0
# Run: 68 exploration: 0.18571499062855834
# Progress: 0, Penalties: -500.0
# Run: 69 exploration: 0.18113861489324412
# Progress: 0, Penalties: -500.0
# Run: 70 exploration: 0.1766750098868833
# Progress: 0, Penalties: -500.0
# Run: 71 exploration: 0.17232139672110608
# Progress: 0, Penalties: -500.0
# Run: 72 exploration: 0.1680750649847135
# Progress: 0, Penalties: -500.0
# Run: 73 exploration: 0.16393337105626896
# Progress: 0, Penalties: -500.0
# Run: 74 exploration: 0.15989373645827015
# Progress: 0, Penalties: -500.0
# Run: 75 exploration: 0.15595364625187502
# Progress: 0, Penalties: -500.0
# Run: 76 exploration: 0.15211064747118813
# Progress: 0, Penalties: -500.0
# Run: 77 exploration: 0.14836234759612674
# Progress: 0, Penalties: -500.0
# Run: 78 exploration: 0.14470641306291995
# Progress: 0, Penalties: -500.0
# Run: 79 exploration: 0.1411405678113106
# Progress: 0, Penalties: -500.0
# Run: 80 exploration: 0.13766259186755953
# Progress: 0, Penalties: -500.0
# Run: 81 exploration: 0.1342703199623628
# Progress: 0, Penalties: -500.0
# Run: 82 exploration: 0.13096164018283088
# Progress: 0, Penalties: -500.0
# Run: 83 exploration: 0.12773449265768405
# Progress: 0, Penalties: -500.0
# Run: 84 exploration: 0.12458686827484408
# Progress: 0, Penalties: -500.0
# Run: 85 exploration: 0.12151680743063292
# Progress: 0, Penalties: -500.0
# Run: 86 exploration: 0.11852239880978759
# Progress: 0, Penalties: -500.0
# Run: 87 exploration: 0.11560177819554132
# Progress: 0, Penalties: -500.0
# Run: 88 exploration: 0.11275312730902597
# Progress: 0, Penalties: -500.0
# Run: 89 exploration: 0.10997467267727334
# Progress: 0, Penalties: -500.0
# Run: 90 exploration: 0.10726468452911139
# Progress: 0, Penalties: -500.0
# Run: 91 exploration: 0.10462147571826785
# Progress: 0, Penalties: -500.0
# Run: 92 exploration: 0.1020434006730098
# Progress: 0, Penalties: -500.0
# Run: 93 exploration: 0.09952885437166727
# Progress: 0, Penalties: -500.0
# Run: 94 exploration: 0.09707627134340165
# Progress: 0, Penalties: -500.0
# Run: 95 exploration: 0.09468412469359642
# Progress: 0, Penalties: -500.0
# Run: 96 exploration: 0.09235092515326493
# Progress: 0, Penalties: -500.0
# Run: 97 exploration: 0.090075220151882
# Progress: 0, Penalties: -500.0
# Run: 98 exploration: 0.08785559291306312
# Progress: 0, Penalties: -500.0
# Run: 99 exploration: 0.085690661572528
# Progress: 0, Penalties: -500.0
# Run: 100 exploration: 0.08357907831779839
# Progress: 0, Penalties: -500.0
# Run: 101 exploration: 0.08151952854909685
# Progress: 0, Penalties: -500.0
# Run: 102 exploration: 0.0795107300609206
# Progress: 0, Penalties: -500.0
# Run: 103 exploration: 0.07755143224378508
# Progress: 0, Penalties: -500.0
# Run: 104 exploration: 0.07564041530563637
# Progress: 0, Penalties: -500.0
# Run: 105 exploration: 0.07377648951245075
# Progress: 0, Penalties: -500.0
# Run: 106 exploration: 0.07195849444754661
# Progress: 0, Penalties: -500.0
# Run: 107 exploration: 0.07018529828914877
# Progress: 0, Penalties: -500.0
# Run: 108 exploration: 0.06845579710575411
# Progress: 0, Penalties: -500.0
# Run: 109 exploration: 0.06676891416886219
# Progress: 0, Penalties: -500.0
# Run: 110 exploration: 0.06512359928264068
# Progress: 0, Penalties: -500.0
# Run: 111 exploration: 0.06351882813010926
# Progress: 0, Penalties: -500.0
# Run: 112 exploration: 0.0619536016354338
# Progress: 0, Penalties: -500.0
# Run: 113 exploration: 0.06042694534193741
# Progress: 0, Penalties: -500.0
# Run: 114 exploration: 0.058937908805435694
# Progress: 0, Penalties: -500.0
# Run: 115 exploration: 0.057485565002523165
# Progress: 0, Penalties: -500.0
# Run: 116 exploration: 0.056069009753439716
# Progress: 0, Penalties: -500.0
# Run: 117 exploration: 0.054687361159159405
# Progress: 0, Penalties: -500.0
# Run: 118 exploration: 0.05333975905234998
# Progress: 0, Penalties: -500.0
# Run: 119 exploration: 0.05202536446186214
# Progress: 0, Penalties: -500.0
# Run: 120 exploration: 0.05074335909041462
# Progress: 0, Penalties: -500.0
# Run: 121 exploration: 0.04949294480515025
# Progress: 0, Penalties: -500.0
# Run: 122 exploration: 0.04827334314074544
# Progress: 0, Penalties: -500.0
# Run: 123 exploration: 0.04708379481476431
# Progress: 0, Penalties: -500.0
# Run: 124 exploration: 0.04592355925495562
# Progress: 0, Penalties: -500.0
# Run: 125 exploration: 0.044791914138197234
# Progress: 0, Penalties: -500.0
# Run: 126 exploration: 0.0436881549408027
# Progress: 0, Penalties: -500.0
# Run: 127 exploration: 0.042611594499908576
# Progress: 0, Penalties: -500.0
# Run: 128 exploration: 0.041561562585670446
# Progress: 0, Penalties: -500.0
# Run: 129 exploration: 0.040537405484000505
# Progress: 0, Penalties: -500.0
# Run: 130 exploration: 0.03953848558958756
# Progress: 0, Penalties: -500.0
# Run: 131 exploration: 0.03856418100894578
# Progress: 0, Penalties: -500.0
# Run: 132 exploration: 0.037613885173244585
# Progress: 0, Penalties: -500.0
# Run: 133 exploration: 0.036687006460680086
# Progress: 0, Penalties: -500.0
# Run: 134 exploration: 0.03578296782815111
# Progress: 0, Penalties: -500.0
# Run: 135 exploration: 0.034901206452012196
# Progress: 0, Penalties: -500.0
# Run: 136 exploration: 0.0340411733776783
# Progress: 0, Penalties: -500.0
# Run: 137 exploration: 0.03320233317786474
# Progress: 0, Penalties: -500.0
# Run: 138 exploration: 0.032384163619248445
# Progress: 0, Penalties: -500.0
# Run: 139 exploration: 0.03158615533734306
# Progress: 0, Penalties: -500.0
# Run: 140 exploration: 0.03080781151938607
# Progress: 0, Penalties: -500.0
# Run: 141 exploration: 0.030048647595040133
# Progress: 0, Penalties: -500.0
# Run: 142 exploration: 0.02930819093471604
# Progress: 0, Penalties: -500.0
# Run: 143 exploration: 0.028585980555329665
# Progress: 0, Penalties: -500.0
# Run: 144 exploration: 0.027881566833309668
# Progress: 0, Penalties: -500.0
# Run: 145 exploration: 0.027194511224677108
# Progress: 0, Penalties: -500.0
# Run: 146 exploration: 0.026524385992022885
# Progress: 0, Penalties: -500.0
# Run: 147 exploration: 0.025870773938213083
# Progress: 0, Penalties: -500.0
# Run: 148 exploration: 0.025233268146656218
# Progress: 0, Penalties: -500.0
# Run: 149 exploration: 0.024611471727970777
# Progress: 0, Penalties: -500.0
# Run: 150 exploration: 0.024004997572895544
# Progress: 0, Penalties: -500.0
# Run: 151 exploration: 0.023413468111288496
# Progress: 0, Penalties: -500.0
# Run: 152 exploration: 0.022836515077064374
# Progress: 0, Penalties: -500.0
# Run: 153 exploration: 0.02227377927892498
# Progress: 0, Penalties: -500.0
# Run: 154 exploration: 0.02172491037673884
# Progress: 0, Penalties: -500.0
# Run: 155 exploration: 0.021189566663431227
# Progress: 0, Penalties: -500.0
# Run: 156 exploration: 0.02066741485224926
# Progress: 0, Penalties: -500.0
# Run: 157 exploration: 0.020158129869268685
# Progress: 0, Penalties: -500.0
# Run: 158 exploration: 0.01966139465101408
# Progress: 0, Penalties: -500.0
# Run: 159 exploration: 0.019176899947065822
# Progress: 0, Penalties: -500.0
# Run: 160 exploration: 0.01870434412753144
# Progress: 0, Penalties: -500.0
# Run: 161 exploration: 0.018243432995261016
# Progress: 0, Penalties: -500.0
# Run: 162 exploration: 0.017793879602690178
# Progress: 0, Penalties: -500.0
# Run: 163 exploration: 0.017355404073196093
# Progress: 0, Penalties: -500.0
# Run: 164 exploration: 0.01692773342685605
# Progress: 0, Penalties: -500.0
# Run: 165 exploration: 0.016510601410499478
# Progress: 0, Penalties: -500.0
# Run: 166 exploration: 0.01610374833194767
# Progress: 0, Penalties: -500.0
# Run: 167 exploration: 0.015706920898338278
# Progress: 0, Penalties: -500.0
# Run: 168 exploration: 0.015319872058433806
# Progress: 0, Penalties: -500.0
# Run: 169 exploration: 0.014942360848816076
# Progress: 0, Penalties: -500.0
# Run: 170 exploration: 0.014574152243870455
# Progress: 0, Penalties: -500.0
# Run: 171 exploration: 0.014215017009466998
# Progress: 0, Penalties: -500.0
# Run: 172 exploration: 0.013864731560247048
# Progress: 0, Penalties: -500.0
# Run: 173 exploration: 0.013523077820426652
# Progress: 0, Penalties: -500.0
# Run: 174 exploration: 0.013189843088029961
# Progress: 0, Penalties: -500.0
# Run: 175 exploration: 0.012864819902468246
# Progress: 0, Penalties: -500.0
# Run: 176 exploration: 0.012547805915382022
# Progress: 0, Penalties: -500.0
# Run: 177 exploration: 0.012238603764665835
# Progress: 0, Penalties: -500.0
# Run: 178 exploration: 0.011937020951597382
# Progress: 0, Penalties: -500.0
# Run: 179 exploration: 0.011642869720994313
# Progress: 0, Penalties: -500.0
# Run: 180 exploration: 0.011355966944324294
# Progress: 0, Penalties: -500.0
# Run: 181 exploration: 0.011076134005695343
# Progress: 0, Penalties: -500.0
# Run: 182 exploration: 0.010803196690655797
# Progress: 0, Penalties: -500.0
# Run: 183 exploration: 0.010536985077734222
# Progress: 0, Penalties: -500.0
# Run: 184 exploration: 0.010277333432652136
# Progress: 0, Penalties: -500.0
# Run: 185 exploration: 0.010024080105143478
# Progress: 0, Penalties: -500.0
# Run: 186 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 187 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 188 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 189 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 190 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 191 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 192 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 193 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 194 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 195 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 196 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 197 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 198 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 199 exploration: 0.01
# Progress: 0, Penalties: -500.0
# Run: 200 exploration: 0.01
# Progress: 0, Penalties: -500.0
